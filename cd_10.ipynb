# %% [markdown]
# <a href="https://colab.research.google.com/github/learning710/11239A090_Compiler_Design_Lab/blob/main/cd_10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def tokenize(expr):
 tokens = []
 for t in expr.split():
  if t.isalpha():
    tokens.append(("ID", t))
  else:
    tokens.append(("OP", t))
 return tokens
print(tokenize("ITEM + ITEM - DISCOUNT"))
# Out:
# [('ID', 'ITEM'), ('OP', '+'), ('ID', 'ITEM'), ('OP', '-'), ('ID', 'DISCOUNT')]
